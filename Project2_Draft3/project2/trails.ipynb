# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine

# from api_key import api_key
api_key = "200602075-3dd15f21d86fec1206fac0fe2d9117c8"
lat = "40.0274"
lon = "-105.2519"
maxDistance = "1000"
maxResults = "1000"

url = f"https://www.hikingproject.com/data/get-trails?lat={lat}&lon={lon}9&maxDistance={maxDistance}&maxResults={maxResults}&key={api_key}"


response = requests.get(url)
response_json = response.json()
response_json

#print(jsonload)
# df = pd.read_json(response_json(["trails"]))
# # print(url)
# # print(json.dumps(response_json, indent=4,))
# df
# Out:
# {'trails': [{'id': 7001635,
#    'name': 'Four Pass Loop',
#    'type': 'Featured Hike',
#    'summary': "An all-time journey over four 12,500' alpine passes, circumnavigating the Maroon Bells.",
#    'difficulty': 'blueBlack',
#    'stars': 5,
#    'starVotes': 142,
#    'location': 'Snowmass Village, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7001635/four-pass-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7007432_sqsmall_1554322843.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7007432_small_1554322843.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7007432_smallMed_1554322843.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7007432_medium_1554322843.jpg',
#    'length': 27.1,
#    'ascent': 7327,
#    'descent': -7329,
#    'high': 12454,
#    'low': 9571,
#    'longitude': -106.9407,
#    'latitude': 39.0985,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'One messy section of avalanche debree, but otherwise perfect.',
#    'conditionDate': '2019-09-20 15:12:10'},
#   {'id': 7006663,
#    'name': 'Monarch Lake to Crater Lake',
#    'type': 'Featured Hike',
#    'summary': 'Gorgeous scenery with waterfalls and wildflowers ending at a breathtaking cirque and glacier lake.',
#    'difficulty': 'blue',
#    'stars': 4.9,
#    'starVotes': 67,
#    'location': 'Granby, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7006663/monarch-lake-to-crater-lake',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7002724_sqsmall_1554227142.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7002724_small_1554227142.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7002724_smallMed_1554227142.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7002724_medium_1554227142.jpg',
#    'length': 14.9,
#    'ascent': 2017,
#    'descent': -2017,
#    'high': 10343,
#    'low': 8350,
#    'longitude': -105.7463,
#    'latitude': 40.1108,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-09-23 09:15:01'},
#   {'id': 7002175,
#    'name': 'Sky Pond',
#    'type': 'Featured Hike',
#    'summary': 'Sky Pond is in a deep valley carved by Taylor Glacier and capped by Taylor and Powell Peak.',
#    'difficulty': 'blueBlack',
#    'stars': 4.9,
#    'starVotes': 228,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7002175/sky-pond',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7053480_sqsmall_1555703487.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7053480_small_1555703487.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7053480_smallMed_1555703487.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7053480_medium_1555703487.jpg',
#    'length': 8.3,
#    'ascent': 2000,
#    'descent': -1999,
#    'high': 11014,
#    'low': 9162,
#    'longitude': -105.6403,
#    'latitude': 40.3105,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Muddy - Starting to get wet up there with constant "in the clouds" coverage.',
#    'conditionDate': '2019-09-30 07:21:48'},
#   {'id': 7000130,
#    'name': 'Bear Peak Out and Back',
#    'type': 'Featured Hike',
#    'summary': 'A must-do hike for Boulder locals and visitors alike!',
#    'difficulty': 'blueBlack',
#    'stars': 4.6,
#    'starVotes': 108,
#    'location': 'Boulder, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7000130/bear-peak-out-and-back',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7005382_sqsmall_1554312030.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7005382_small_1554312030.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7005382_smallMed_1554312030.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7005382_medium_1554312030.jpg',
#    'length': 5.7,
#    'ascent': 2541,
#    'descent': -2540,
#    'high': 8342,
#    'low': 6103,
#    'longitude': -105.2755,
#    'latitude': 39.9787,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-08-10 16:37:58'},
#   {'id': 7000276,
#    'name': 'Emerald Lake',
#    'type': 'Featured Hike',
#    'summary': 'An easy to moderate out and back that culminates at views of Emerald Lake.',
#    'difficulty': 'greenBlue',
#    'stars': 4.7,
#    'starVotes': 263,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7000276/emerald-lake',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7017842_sqsmall_1554829871.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7017842_small_1554829871.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7017842_smallMed_1554829871.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7017842_medium_1554829871.jpg',
#    'length': 3.3,
#    'ascent': 661,
#    'descent': -651,
#    'high': 10104,
#    'low': 9476,
#    'longitude': -105.6457,
#    'latitude': 40.312,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-09-14 20:55:37'},
#   {'id': 7000487,
#    'name': 'Longs Peak - Keyhole Route',
#    'type': 'Featured Hike',
#    'summary': 'A beautiful and rewarding route to the summit of an iconic Colorado peak.',
#    'difficulty': 'black',
#    'stars': 4.8,
#    'starVotes': 85,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7000487/longs-peak-keyhole-route',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7037747_sqsmall_1555086694.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7037747_small_1555086694.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7037747_smallMed_1555086694.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7037747_medium_1555086694.jpg',
#    'length': 14.2,
#    'ascent': 5525,
#    'descent': -5524,
#    'high': 14214,
#    'low': 9412,
#    'longitude': -105.5566,
#    'latitude': 40.2717,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': '',
#    'conditionDate': '2019-09-19 06:53:44'},
#   {'id': 7004226,
#    'name': "Sunshine Lion's Lair Loop",
#    'type': 'Featured Hike',
#    'summary': 'Great Mount Sanitas views are the reward for this gentler loop in Sunshine Canyon.',
#    'difficulty': 'blue',
#    'stars': 4.5,
#    'starVotes': 103,
#    'location': 'Boulder, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7004226/sunshine-lions-lair-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039883_sqsmall_1555092747.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7039883_small_1555092747.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039883_smallMed_1555092747.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7039883_medium_1555092747.jpg',
#    'length': 5.3,
#    'ascent': 1261,
#    'descent': -1282,
#    'high': 6800,
#    'low': 5530,
#    'longitude': -105.2979,
#    'latitude': 40.02,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry - Careful of ticks in the high grass along Sunshine right now!',
#    'conditionDate': '2019-07-10 14:09:36'},
#   {'id': 7011192,
#    'name': 'Boulder Skyline Traverse',
#    'type': 'Featured Hike',
#    'summary': 'The classic long mountain route in Boulder.',
#    'difficulty': 'black',
#    'stars': 4.7,
#    'starVotes': 71,
#    'location': 'Superior, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7011192/boulder-skyline-traverse',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7048859_sqsmall_1555540136.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7048859_small_1555540136.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7048859_smallMed_1555540136.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7048859_medium_1555540136.jpg',
#    'length': 16.3,
#    'ascent': 5409,
#    'descent': -5492,
#    'high': 8492,
#    'low': 5417,
#    'longitude': -105.2582,
#    'latitude': 39.9388,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-07-30 17:52:30'},
#   {'id': 7002074,
#    'name': 'Quandary Peak',
#    'type': 'Featured Hike',
#    'summary': 'A popular and easy 14er just outside Breckenridge.',
#    'difficulty': 'blueBlack',
#    'stars': 4.4,
#    'starVotes': 104,
#    'location': 'Breckenridge, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7002074/quandary-peak',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7033447_sqsmall_1554998013.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7033447_small_1554998013.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7033447_smallMed_1554998013.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7033447_medium_1554998013.jpg',
#    'length': 6.4,
#    'ascent': 3169,
#    'descent': -3178,
#    'high': 14184,
#    'low': 11006,
#    'longitude': -106.0619,
#    'latitude': 39.3854,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-09-25 19:25:54'},
#   {'id': 7006795,
#    'name': 'High Lonesome Loop',
#    'type': 'Featured Hike',
#    'summary': 'A backcountry trail providing the best of high alpine hiking, with stunning views along the Divide.',
#    'difficulty': 'blueBlack',
#    'stars': 4.8,
#    'starVotes': 68,
#    'location': 'Nederland, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7006795/high-lonesome-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7034581_sqsmall_1555000565.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7034581_small_1555000565.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7034581_smallMed_1555000565.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7034581_medium_1555000565.jpg',
#    'length': 15.7,
#    'ascent': 3162,
#    'descent': -3162,
#    'high': 12035,
#    'low': 8988,
#    'longitude': -105.5951,
#    'latitude': 39.9516,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-09-02 21:51:16'},
#   {'id': 7003636,
#    'name': 'Grays and Torreys Peaks',
#    'type': 'Featured Hike',
#    'summary': 'Summit two 14ers on the Continental Divide along an alpine lollipop loop close to Denver',
#    'difficulty': 'blueBlack',
#    'stars': 4.4,
#    'starVotes': 102,
#    'location': 'Georgetown, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7003636/grays-and-torreys-peaks',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7033157_sqsmall_1554997360.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7033157_small_1554997360.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7033157_smallMed_1554997360.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7033157_medium_1554997360.jpg',
#    'length': 8.3,
#    'ascent': 3479,
#    'descent': -3466,
#    'high': 14246,
#    'low': 11242,
#    'longitude': -105.7846,
#    'latitude': 39.6609,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-09-02 16:06:23'},
#   {'id': 7001090,
#    'name': 'Best of Bear Lake Area Loop',
#    'type': 'Featured Hike',
#    'summary': 'A splendid loop highlighting the natural beauty in and around the Bear Lake area.',
#    'difficulty': 'blue',
#    'stars': 4.6,
#    'starVotes': 90,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7001090/best-of-bear-lake-area-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7017842_sqsmall_1554829871.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7017842_small_1554829871.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7017842_smallMed_1554829871.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7017842_medium_1554829871.jpg',
#    'length': 5.7,
#    'ascent': 1293,
#    'descent': -1309,
#    'high': 10194,
#    'low': 9273,
#    'longitude': -105.6461,
#    'latitude': 40.312,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Some Mud',
#    'conditionDate': '2019-09-19 16:30:09'},
#   {'id': 7001041,
#    'name': 'Chasm Lake',
#    'type': 'Featured Hike',
#    'summary': 'A must-do RMNP hike that leads to and from an incredible alpine lake.',
#    'difficulty': 'blueBlack',
#    'stars': 4.7,
#    'starVotes': 77,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7001041/chasm-lake',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7006507_sqsmall_1554320883.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7006507_small_1554320883.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7006507_smallMed_1554320883.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7006507_medium_1554320883.jpg',
#    'length': 8.2,
#    'ascent': 2766,
#    'descent': -2766,
#    'high': 11675,
#    'low': 9430,
#    'longitude': -105.5566,
#    'latitude': 40.2716,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-09-23 09:10:09'},
#   {'id': 7003401,
#    'name': 'Hanging Lake',
#    'type': 'Featured Hike',
#    'summary': "A true treasure of Glenwood Canyon, Hanging Lake is one of Colorado's most popular trails.",
#    'difficulty': 'blue',
#    'stars': 4.6,
#    'starVotes': 117,
#    'location': 'Glenwood Springs, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7003401/hanging-lake',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7034279_sqsmall_1554999928.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7034279_small_1554999928.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7034279_smallMed_1554999928.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7034279_medium_1554999928.jpg',
#    'length': 2.6,
#    'ascent': 1037,
#    'descent': -1037,
#    'high': 7145,
#    'low': 6108,
#    'longitude': -107.19,
#    'latitude': 39.5893,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-06-30 22:31:10'},
#   {'id': 7018920,
#    'name': 'Ouzel Falls & Back',
#    'type': 'Featured Hike',
#    'summary': 'Three waterfalls, one mountain creek, and 5.5 miles of alpine bliss.',
#    'difficulty': 'blue',
#    'stars': 4.5,
#    'starVotes': 96,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7018920/ouzel-falls-back',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7018971_sqsmall_1554832365.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7018971_small_1554832365.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7018971_smallMed_1554832365.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7018971_medium_1554832365.jpg',
#    'length': 5.3,
#    'ascent': 921,
#    'descent': -921,
#    'high': 9357,
#    'low': 8511,
#    'longitude': -105.5664,
#    'latitude': 40.2078,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Mostly Dry',
#    'conditionDate': '2019-08-23 19:33:37'},
#   {'id': 7004682,
#    'name': 'Royal Arch Out and Back',
#    'type': 'Featured Hike',
#    'summary': 'A classic Boulder hike to a natural arch with great views.',
#    'difficulty': 'blueBlack',
#    'stars': 4.4,
#    'starVotes': 145,
#    'location': 'Boulder, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7004682/royal-arch-out-and-back',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7002679_sqsmall_1554226731.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7002679_small_1554226731.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7002679_smallMed_1554226731.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7002679_medium_1554226731.jpg',
#    'length': 3.3,
#    'ascent': 1311,
#    'descent': -1312,
#    'high': 6917,
#    'low': 5691,
#    'longitude': -105.283,
#    'latitude': 39.9997,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-07-21 14:20:07'},
#   {'id': 7002439,
#    'name': 'Walker Ranch',
#    'type': 'Featured Hike',
#    'summary': 'An awesome and challenging hike near Boulder with great scenery.',
#    'difficulty': 'blueBlack',
#    'stars': 4.5,
#    'starVotes': 119,
#    'location': 'Coal Creek, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7002439/walker-ranch',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039625_sqsmall_1555092312.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7039625_small_1555092312.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039625_smallMed_1555092312.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7039625_medium_1555092312.jpg',
#    'length': 7.6,
#    'ascent': 1594,
#    'descent': -1585,
#    'high': 7335,
#    'low': 6439,
#    'longitude': -105.3378,
#    'latitude': 39.9511,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-08-11 12:20:56'},
#   {'id': 7011191,
#    'name': 'Green Mountain via Ranger/Saddle Rock Loop',
#    'type': 'Featured Hike',
#    'summary': 'A loop with a variety of terrain, a lot of climbing, and great views of Boulder.',
#    'difficulty': 'blueBlack',
#    'stars': 4.5,
#    'starVotes': 77,
#    'location': 'Boulder, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7011191/green-mountain-via-rangersaddle-rock-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003740_sqsmall_1554235436.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7003740_small_1554235436.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003740_smallMed_1554235436.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7003740_medium_1554235436.jpg',
#    'length': 4.9,
#    'ascent': 2305,
#    'descent': -2277,
#    'high': 8099,
#    'low': 5806,
#    'longitude': -105.2928,
#    'latitude': 39.9975,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-08-03 18:22:28'},
#   {'id': 7003796,
#    'name': 'Section 16/Palmer Loop',
#    'type': 'Featured Hike',
#    'summary': 'A favorite loop in the Springs area.',
#    'difficulty': 'blue',
#    'stars': 4.5,
#    'starVotes': 71,
#    'location': 'Manitou Springs, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7003796/section-16palmer-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7060379_sqsmall_1562771833.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7060379_small_1562771833.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7060379_smallMed_1562771833.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7060379_medium_1562771833.jpg',
#    'length': 5.9,
#    'ascent': 1287,
#    'descent': -1288,
#    'high': 7845,
#    'low': 6633,
#    'longitude': -104.8903,
#    'latitude': 38.8228,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-09-19 15:04:39'},
#   {'id': 7001739,
#    'name': 'Mt. Bierstadt – West Slopes',
#    'type': 'Featured Hike',
#    'summary': "An easy intro to Colorado's 14ers on the standard West Slopes route.",
#    'difficulty': 'blueBlack',
#    'stars': 4.3,
#    'starVotes': 91,
#    'location': 'Georgetown, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7001739/mt-bierstadt-west-slopes',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7001090_sqsmall_1554217633.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7001090_small_1554217633.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7001090_smallMed_1554217633.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7001090_medium_1554217633.jpg',
#    'length': 7.2,
#    'ascent': 2625,
#    'descent': -2624,
#    'high': 14016,
#    'low': 11509,
#    'longitude': -105.7102,
#    'latitude': 39.5964,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry, Snowy',
#    'conditionDate': '2019-09-22 14:13:06'},
#   {'id': 7000000,
#    'name': 'Mount Sanitas Loop',
#    'type': 'Featured Hike',
#    'summary': 'Very popular and scenic loop right from the edge of town.',
#    'difficulty': 'blueBlack',
#    'stars': 4.1,
#    'starVotes': 102,
#    'location': 'Boulder, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7000000/mount-sanitas-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039883_sqsmall_1555092747.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7039883_small_1555092747.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039883_smallMed_1555092747.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7039883_medium_1555092747.jpg',
#    'length': 3.2,
#    'ascent': 1281,
#    'descent': -1280,
#    'high': 6780,
#    'low': 5521,
#    'longitude': -105.2977,
#    'latitude': 40.0202,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-08-27 15:10:20'},
#   {'id': 7002038,
#    'name': 'Mt. Elbert',
#    'type': 'Featured Hike',
#    'summary': 'The highest mountain in Colorado is also one of the easiest 14ers.',
#    'difficulty': 'blueBlack',
#    'stars': 4.4,
#    'starVotes': 70,
#    'location': 'Leadville North, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7002038/mt-elbert',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7035542_sqsmall_1555020368.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7035542_small_1555020368.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7035542_smallMed_1555020368.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7035542_medium_1555020368.jpg',
#    'length': 8.9,
#    'ascent': 4410,
#    'descent': -4410,
#    'high': 14405,
#    'low': 10063,
#    'longitude': -106.4123,
#    'latitude': 39.1521,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-09-14 20:57:08'},
#   {'id': 7004911,
#    'name': 'Mt. Galbraith Park Loop',
#    'type': 'Featured Hike',
#    'summary': "A fun singletrack lollipop loop up and around Mt. Galbraith's peak with views in all directions.",
#    'difficulty': 'blue',
#    'stars': 4,
#    'starVotes': 77,
#    'location': 'Golden, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7004911/mt-galbraith-park-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7005037_sqsmall_1554311310.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7005037_small_1554311310.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7005037_smallMed_1554311310.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7005037_medium_1554311310.jpg',
#    'length': 4.3,
#    'ascent': 918,
#    'descent': -919,
#    'high': 7192,
#    'low': 6289,
#    'longitude': -105.2541,
#    'latitude': 39.7736,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry - Rattlesnakes are very active in this area.',
#    'conditionDate': '2019-08-20 16:53:49'},
#   {'id': 7000141,
#    'name': 'North Table Loop Trail',
#    'type': 'Featured Hike',
#    'summary': 'A rolling grassland trail that circumnavigates North Table Mountain.',
#    'difficulty': 'blue',
#    'stars': 3.9,
#    'starVotes': 76,
#    'location': 'Golden, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7000141/north-table-loop-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7044543_sqsmall_1555530554.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7044543_small_1555530554.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7044543_smallMed_1555530554.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7044543_medium_1555530554.jpg',
#    'length': 7.7,
#    'ascent': 1058,
#    'descent': -1056,
#    'high': 6486,
#    'low': 5851,
#    'longitude': -105.2297,
#    'latitude': 39.782,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-09-21 08:39:48'},
#   {'id': 7001581,
#    'name': 'Loch Vale',
#    'type': 'Featured Hike',
#    'summary': "One of RMNP's premier hikes featuring some of the park's biggest draws.",
#    'difficulty': 'blue',
#    'stars': 4.8,
#    'starVotes': 58,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7001581/loch-vale',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7000658_sqsmall_1554159500.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7000658_small_1554159500.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7000658_smallMed_1554159500.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7000658_medium_1554159500.jpg',
#    'length': 6,
#    'ascent': 1083,
#    'descent': -1086,
#    'high': 10223,
#    'low': 9136,
#    'longitude': -105.6403,
#    'latitude': 40.3104,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Muddy - Starting to get wet up there with constant "in the clouds" coverage.',
#    'conditionDate': '2019-09-30 07:22:27'},
#   {'id': 7006672,
#    'name': 'Hessie to Lost Lake',
#    'type': 'Featured Hike',
#    'summary': 'A relatively approachable alpine hike with easy access.',
#    'difficulty': 'greenBlue',
#    'stars': 4.2,
#    'starVotes': 64,
#    'location': 'Nederland, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7006672/hessie-to-lost-lake',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7029411_sqsmall_1554924471.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7029411_small_1554924471.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7029411_smallMed_1554924471.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7029411_medium_1554924471.jpg',
#    'length': 4.4,
#    'ascent': 860,
#    'descent': -860,
#    'high': 9834,
#    'low': 8988,
#    'longitude': -105.5951,
#    'latitude': 39.9516,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-09-28 13:42:27'},
#   {'id': 7010213,
#    'name': 'Pawnee-Buchanan Loop',
#    'type': 'Featured Hike',
#    'summary': 'One of the top long loops in Colorado.',
#    'difficulty': 'blueBlack',
#    'stars': 4.8,
#    'starVotes': 39,
#    'location': 'Nederland, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7010213/pawnee-buchanan-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7049405_sqsmall_1555541334.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7049405_small_1555541334.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7049405_smallMed_1555541334.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7049405_medium_1555541334.jpg',
#    'length': 26.5,
#    'ascent': 6632,
#    'descent': -6615,
#    'high': 12528,
#    'low': 8820,
#    'longitude': -105.5843,
#    'latitude': 40.0784,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-09-25 23:22:10'},
#   {'id': 7006885,
#    'name': 'South Arapaho Peak',
#    'type': 'Featured Hike',
#    'summary': 'One of the most popular and worthwhile summits in the Indian Peaks Wilderness.',
#    'difficulty': 'blueBlack',
#    'stars': 4.8,
#    'starVotes': 43,
#    'location': 'Nederland, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7006885/south-arapaho-peak',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7024359_sqsmall_1554846789.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7024359_small_1554846789.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7024359_smallMed_1554846789.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7024359_medium_1554846789.jpg',
#    'length': 8.6,
#    'ascent': 3111,
#    'descent': -3110,
#    'high': 13269,
#    'low': 10158,
#    'longitude': -105.6341,
#    'latitude': 39.9952,
#    'conditionStatus': 'Minor Issues',
#    'conditionDetails': 'Mostly Dry, Some Mud',
#    'conditionDate': '2019-08-23 15:31:44'},
#   {'id': 7011049,
#    'name': 'Chavez and Beaver Brook Trail Loop',
#    'type': 'Featured Hike',
#    'summary': 'A rolling trail with lots of shade, following a creek with frequent crossings.',
#    'difficulty': 'blueBlack',
#    'stars': 4.4,
#    'starVotes': 56,
#    'location': 'Genesee, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7011049/chavez-and-beaver-brook-trail-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7013652_sqsmall_1554822939.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7013652_small_1554822939.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7013652_smallMed_1554822939.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7013652_medium_1554822939.jpg',
#    'length': 3.9,
#    'ascent': 883,
#    'descent': -883,
#    'high': 7427,
#    'low': 6563,
#    'longitude': -105.3154,
#    'latitude': 39.7168,
#    'conditionStatus': 'Bad / Closed',
#    'conditionDetails': "The road leading to the trailhead of I-70 was completely closed for construction. Sept 23 2019! Couldn't get to the trails",
#    'conditionDate': '2019-09-23 15:08:14'},
#   {'id': 7009683,
#    'name': 'Cub Lake Loop',
#    'type': 'Featured Hike',
#    'summary': 'A loop from the open meadows of Moraine Park up to Cub Lake and back along the Big Thompson River.',
#    'difficulty': 'blue',
#    'stars': 4.3,
#    'starVotes': 63,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7009683/cub-lake-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7000875_sqsmall_1554159764.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7000875_small_1554159764.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7000875_smallMed_1554159764.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7000875_medium_1554159764.jpg',
#    'length': 6,
#    'ascent': 635,
#    'descent': -633,
#    'high': 8685,
#    'low': 8063,
#    'longitude': -105.6158,
#    'latitude': 40.3562,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry - All clear! A few roots/rocks, but otherwise no problems as of late August.',
#    'conditionDate': '2019-08-23 08:10:22'},
#   {'id': 7002202,
#    'name': 'DeCaliBron',
#    'type': 'Featured Hike',
#    'summary': 'Summit four Fourteeners (Democrat, Cameron, Lincoln, and Bross) in one fell swoop.',
#    'difficulty': 'blueBlack',
#    'stars': 4.4,
#    'starVotes': 57,
#    'location': 'Copper Mountain, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7002202/decalibron',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7063380_sqsmall_1569542544.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7063380_small_1569542544.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7063380_smallMed_1569542544.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7063380_medium_1569542544.jpg',
#    'length': 7,
#    'ascent': 3003,
#    'descent': -3003,
#    'high': 14220,
#    'low': 12025,
#    'longitude': -106.1294,
#    'latitude': 39.3279,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-09-20 11:38:34'},
#   {'id': 7002479,
#    'name': 'Buffalo Mountain Loop',
#    'type': 'Featured Hike',
#    'summary': 'An amazing hike circumnavigating Buffalo Mountain, over Eccles Pass.',
#    'difficulty': 'blueBlack',
#    'stars': 4.8,
#    'starVotes': 42,
#    'location': 'Silverthorne, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7002479/buffalo-mountain-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7001592_sqsmall_1554218985.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7001592_small_1554218985.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7001592_smallMed_1554218985.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7001592_medium_1554218985.jpg',
#    'length': 13.4,
#    'ascent': 2976,
#    'descent': -2960,
#    'high': 11833,
#    'low': 9587,
#    'longitude': -106.1102,
#    'latitude': 39.6199,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Trees cleared',
#    'conditionDate': '2019-09-25 08:00:28'},
#   {'id': 7004315,
#    'name': 'Mitchell Lake Trail Out and Back',
#    'type': 'Featured Hike',
#    'summary': 'An easily accessible, high alpine lake trail surrounded by stunning aspens.',
#    'difficulty': 'blue',
#    'stars': 4.6,
#    'starVotes': 47,
#    'location': 'Nederland, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7004315/mitchell-lake-trail-out-and-back',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7051494_sqsmall_1555692978.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7051494_small_1555692978.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7051494_smallMed_1555692978.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7051494_medium_1555692978.jpg',
#    'length': 5.4,
#    'ascent': 864,
#    'descent': -863,
#    'high': 11387,
#    'low': 10524,
#    'longitude': -105.5817,
#    'latitude': 40.0833,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-09-19 13:32:47'},
#   {'id': 7009398,
#    'name': 'Greyrock Mountain Loop',
#    'type': 'Featured Hike',
#    'summary': 'This great hike rewards you with amazing views!',
#    'difficulty': 'blueBlack',
#    'stars': 4.3,
#    'starVotes': 51,
#    'location': 'Bellvue, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7009398/greyrock-mountain-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7004953_sqsmall_1554311139.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7004953_small_1554311139.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7004953_smallMed_1554311139.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7004953_medium_1554311139.jpg',
#    'length': 7.4,
#    'ascent': 2241,
#    'descent': -2241,
#    'high': 7469,
#    'low': 5571,
#    'longitude': -105.284,
#    'latitude': 40.6948,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry - No snakes this morning , all clear',
#    'conditionDate': '2019-08-07 11:54:06'},
#   {'id': 7001019,
#    'name': 'Betasso Preserve',
#    'type': 'Featured Hike',
#    'summary': 'This hike is easily accessible from Boulder and offers amazing singletrack with beautiful views.',
#    'difficulty': 'blue',
#    'stars': 4.2,
#    'starVotes': 58,
#    'location': 'Boulder, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7001019/betasso-preserve',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7029200_sqsmall_1554920151.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7029200_small_1554920151.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7029200_smallMed_1554920151.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7029200_medium_1554920151.jpg',
#    'length': 6.7,
#    'ascent': 776,
#    'descent': -778,
#    'high': 6575,
#    'low': 6178,
#    'longitude': -105.3446,
#    'latitude': 40.0164,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-06-24 10:31:06'},
#   {'id': 7009076,
#    'name': 'Mountain Lion Trail',
#    'type': 'Featured Hike',
#    'summary': 'Colorado wrapped into one trail offering elevation, lakes, creeks, and mountain views.',
#    'difficulty': 'blue',
#    'stars': 4.5,
#    'starVotes': 50,
#    'location': 'Coal Creek, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7009076/mountain-lion-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7044196_sqsmall_1555109790.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7044196_small_1555109790.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7044196_smallMed_1555109790.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7044196_medium_1555109790.jpg',
#    'length': 6.9,
#    'ascent': 1531,
#    'descent': -1509,
#    'high': 8901,
#    'low': 7627,
#    'longitude': -105.3606,
#    'latitude': 39.8505,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-09-22 11:51:40'},
#   {'id': 7003096,
#    'name': 'Mount Falcon West Loop',
#    'type': 'Featured Hike',
#    'summary': 'Spectacular mountain scenery just minutes from the plains.',
#    'difficulty': 'greenBlue',
#    'stars': 4.3,
#    'starVotes': 55,
#    'location': 'Indian Hills, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7003096/mount-falcon-west-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7002141_sqsmall_1554225326.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7002141_small_1554225326.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7002141_smallMed_1554225326.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7002141_medium_1554225326.jpg',
#    'length': 3.6,
#    'ascent': 638,
#    'descent': -638,
#    'high': 7838,
#    'low': 7257,
#    'longitude': -105.2394,
#    'latitude': 39.6361,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-09-14 14:18:42'},
#   {'id': 7029252,
#    'name': 'Apex-Enchanted Lollipop',
#    'type': 'Featured Hike',
#    'summary': 'This is one of the best hikes on the Front Range.',
#    'difficulty': 'blue',
#    'stars': 4.2,
#    'starVotes': 56,
#    'location': 'West Pleasant View, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7029252/apex-enchanted-lollipop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7004559_sqsmall_1554245622.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7004559_small_1554245622.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7004559_smallMed_1554245622.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7004559_medium_1554245622.jpg',
#    'length': 5.7,
#    'ascent': 1179,
#    'descent': -1179,
#    'high': 7312,
#    'low': 6172,
#    'longitude': -105.2098,
#    'latitude': 39.7162,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-07-28 12:51:13'},
#   {'id': 7001096,
#    'name': 'Bear Lake TH to Fern Lake TH',
#    'type': 'Featured Hike',
#    'summary': "An epic alpine point-to-point made possible by RMNP's free shuttle system.",
#    'difficulty': 'blue',
#    'stars': 4.7,
#    'starVotes': 46,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7001096/bear-lake-th-to-fern-lake-th',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7000772_sqsmall_1554159640.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7000772_small_1554159640.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7000772_smallMed_1554159640.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7000772_medium_1554159640.jpg',
#    'length': 8.5,
#    'ascent': 1180,
#    'descent': -2524,
#    'high': 10656,
#    'low': 8153,
#    'longitude': -105.6464,
#    'latitude': 40.3121,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Mostly Dry - 3 snow patches left- 2 at highest trail point can be avoided and 1 on way from bear is flat. Spikes/ poles not needed.',
#    'conditionDate': '2019-08-04 11:41:15'},
#   {'id': 7004341,
#    'name': "Devil's Head Lookout",
#    'type': 'Featured Hike',
#    'summary': 'A shaded trail to the only remaining fire lookout on the Front Range, offering 360-degree views.',
#    'difficulty': 'greenBlue',
#    'stars': 4.7,
#    'starVotes': 45,
#    'location': 'Deckers, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7004341/devils-head-lookout',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003447_sqsmall_1554234206.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7003447_small_1554234206.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003447_smallMed_1554234206.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7003447_medium_1554234206.jpg',
#    'length': 2.7,
#    'ascent': 887,
#    'descent': -885,
#    'high': 9677,
#    'low': 8832,
#    'longitude': -105.105,
#    'latitude': 39.2693,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry - Stairs to fire tower are closed for maintainance. Open up to the meadow, though, and there are some great views along the way.',
#    'conditionDate': '2019-08-17 11:02:08'},
#   {'id': 7006965,
#    'name': 'Lost Creek Wilderness Loop',
#    'type': 'Featured Hike',
#    'summary': 'A divine hike through massive granite formations, splendid meadows, and lush forest.',
#    'difficulty': 'blueBlack',
#    'stars': 4.5,
#    'starVotes': 35,
#    'location': 'Bailey, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7006965/lost-creek-wilderness-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7030000_sqsmall_1554926007.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7030000_small_1554926007.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7030000_smallMed_1554926007.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7030000_medium_1554926007.jpg',
#    'length': 29.2,
#    'ascent': 6156,
#    'descent': -6156,
#    'high': 10890,
#    'low': 8078,
#    'longitude': -105.4633,
#    'latitude': 39.1363,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry - Was hot and dry when I did this on 8/16. Went through a lot of water. Plan accordingly.',
#    'conditionDate': '2019-08-22 11:55:07'},
#   {'id': 7003978,
#    'name': 'Matthews/Winters Red Rocks Loop',
#    'type': 'Featured Hike',
#    'summary': 'Varied terrain from smooth wide dirt, to rocky singletrack with amazing views in all directions.',
#    'difficulty': 'blueBlack',
#    'stars': 4.2,
#    'starVotes': 51,
#    'location': 'Morrison, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7003978/matthewswinters-red-rocks-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7055205_sqsmall_1555708565.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7055205_small_1555708565.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7055205_smallMed_1555708565.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7055205_medium_1555708565.jpg',
#    'length': 6.9,
#    'ascent': 1189,
#    'descent': -1180,
#    'high': 6774,
#    'low': 6000,
#    'longitude': -105.2047,
#    'latitude': 39.6944,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry - One baby rattlesnake on the trail near Red Rocks. Keep an eye out!',
#    'conditionDate': '2019-09-12 23:43:38'},
#   {'id': 7012750,
#    'name': 'Maxwell Falls Loop',
#    'type': 'Featured Hike',
#    'summary': 'A forested trail with waterfalls, offering a panoramic view of the Conifer area.',
#    'difficulty': 'blue',
#    'stars': 4.2,
#    'starVotes': 55,
#    'location': 'Evergreen, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7012750/maxwell-falls-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7021682_sqsmall_1554840071.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7021682_small_1554840071.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7021682_smallMed_1554840071.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7021682_medium_1554840071.jpg',
#    'length': 5.2,
#    'ascent': 955,
#    'descent': -955,
#    'high': 8398,
#    'low': 7761,
#    'longitude': -105.3608,
#    'latitude': 39.5824,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-07-07 23:16:47'},
#   {'id': 7000425,
#    'name': 'Bear Lake Trail',
#    'type': 'Featured Hike',
#    'summary': 'A short loop that circumnavigates beautiful Bear Lake.',
#    'difficulty': 'green',
#    'stars': 4.2,
#    'starVotes': 56,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7000425/bear-lake-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7005958_sqsmall_1554313233.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7005958_small_1554313233.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7005958_smallMed_1554313233.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7005958_medium_1554313233.jpg',
#    'length': 0.6,
#    'ascent': 45,
#    'descent': -39,
#    'high': 9537,
#    'low': 9499,
#    'longitude': -105.6464,
#    'latitude': 40.3121,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-09-14 20:57:43'},
#   {'id': 7027384,
#    'name': 'Mount Morrison',
#    'type': 'Featured Hike',
#    'summary': 'This out-and-back route features steep climbing and fast, technical descents.',
#    'difficulty': 'black',
#    'stars': 4.3,
#    'starVotes': 50,
#    'location': 'Morrison, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7027384/mount-morrison',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7021687_sqsmall_1554840086.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7021687_small_1554840086.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7021687_smallMed_1554840086.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7021687_medium_1554840086.jpg',
#    'length': 3.6,
#    'ascent': 1975,
#    'descent': -1974,
#    'high': 7860,
#    'low': 5885,
#    'longitude': -105.2019,
#    'latitude': 39.6535,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-08-18 13:25:14'},
#   {'id': 7019523,
#    'name': 'Booth Creek Falls',
#    'type': 'Featured Hike',
#    'summary': 'Deservedly one of the most popular trails in Vail, up to a waterfall and back.',
#    'difficulty': 'blue',
#    'stars': 4.4,
#    'starVotes': 43,
#    'location': 'Vail, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7019523/booth-creek-falls',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7038491_sqsmall_1555088459.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7038491_small_1555088459.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7038491_smallMed_1555088459.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7038491_medium_1555088459.jpg',
#    'length': 3.8,
#    'ascent': 1380,
#    'descent': -1380,
#    'high': 9825,
#    'low': 8445,
#    'longitude': -106.3199,
#    'latitude': 39.6503,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'A little muddy after Friday rain, but not bad.',
#    'conditionDate': '2019-07-27 09:14:17'},
#   {'id': 7006769,
#    'name': 'Castlewood Canyon - Rimrock to Creek Bottom Loop',
#    'type': 'Featured Hike',
#    'summary': 'A fun, rolling trail with a sense of seclusion, great geology, and historical sites.',
#    'difficulty': 'blue',
#    'stars': 4.5,
#    'starVotes': 44,
#    'location': 'Castle Rock, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7006769/castlewood-canyon-rimrock-to-creek-bottom-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7006325_sqsmall_1554320490.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7006325_small_1554320490.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7006325_smallMed_1554320490.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7006325_medium_1554320490.jpg',
#    'length': 4.6,
#    'ascent': 610,
#    'descent': -612,
#    'high': 6561,
#    'low': 6163,
#    'longitude': -104.7682,
#    'latitude': 39.3598,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7018781,
#    'name': 'Bear Creek Falls',
#    'type': 'Featured Hike',
#    'summary': "This quick route gives a true taste of Telluride and it's breathtaking landscapes.",
#    'difficulty': 'greenBlue',
#    'stars': 4.6,
#    'starVotes': 36,
#    'location': 'Telluride, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7018781/bear-creek-falls',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7050753_sqsmall_1555691354.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7050753_small_1555691354.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7050753_smallMed_1555691354.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7050753_medium_1555691354.jpg',
#    'length': 4.7,
#    'ascent': 1076,
#    'descent': -1076,
#    'high': 9888,
#    'low': 8812,
#    'longitude': -107.8119,
#    'latitude': 37.9342,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-08-29 21:10:51'},
#   {'id': 7006771,
#    'name': 'Deer Creek',
#    'type': 'Featured Hike',
#    'summary': 'My favorite local hike. Great views with lots of shade. You have short and long hike options.',
#    'difficulty': 'blue',
#    'stars': 4.4,
#    'starVotes': 43,
#    'location': 'Ken Caryl, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7006771/deer-creek',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7004522_sqsmall_1554245226.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7004522_small_1554245226.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7004522_smallMed_1554245226.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7004522_medium_1554245226.jpg',
#    'length': 7.3,
#    'ascent': 1275,
#    'descent': -1280,
#    'high': 7186,
#    'low': 6101,
#    'longitude': -105.1521,
#    'latitude': 39.5432,
#    'conditionStatus': 'Bad / Closed',
#    'conditionDetails': 'Entire area closed',
#    'conditionDate': '2019-08-21 06:50:24'},
#   {'id': 7022212,
#    'name': 'Garden of the Gods Loop',
#    'type': 'Featured Hike',
#    'summary': 'A longer loop in this spectacular area allows hikers to take in the highlights without the crowds.',
#    'difficulty': 'greenBlue',
#    'stars': 4.1,
#    'starVotes': 45,
#    'location': 'Manitou Springs, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7022212/garden-of-the-gods-loop',
# ...
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7032730_small_1554933750.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7032730_smallMed_1554933750.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7032730_medium_1554933750.jpg',
#    'length': 3,
#    'ascent': 320,
#    'descent': -189,
#    'high': 10115,
#    'low': 9853,
#    'longitude': -106.0299,
#    'latitude': 39.4666,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-07-14 13:53:40'},
#   {'id': 7004781,
#    'name': 'CDT: South Boulder Creek to Rollins Pass',
#    'type': 'Trail',
#    'summary': 'Part of the Continental Divide Scenic Trail, this section hosts stunning views along open ridgeline.',
#    'difficulty': 'blueBlack',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Winter Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7004781/cdt-south-boulder-creek-to-rollins-pass',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7049287_sqsmall_1555541030.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7049287_small_1555541030.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7049287_smallMed_1555541030.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7049287_medium_1555541030.jpg',
#    'length': 4.6,
#    'ascent': 878,
#    'descent': -1103,
#    'high': 12152,
#    'low': 11372,
#    'longitude': -105.6982,
#    'latitude': 39.8719,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7033084,
#    'name': 'Rock House Trail',
#    'type': 'Trail',
#    'summary': "This trail extends St. Mary's Glacier Trail and leads to a rock house after you get to the top of Mary's.",
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Winter Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7033084/rock-house-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7029823_sqsmall_1554925320.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7029823_small_1554925320.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7029823_smallMed_1554925320.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7029823_medium_1554925320.jpg',
#    'length': 1,
#    'ascent': 220,
#    'descent': -159,
#    'high': 11680,
#    'low': 11460,
#    'longitude': -105.6657,
#    'latitude': 39.8401,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Dry',
#    'conditionDate': '2019-07-15 16:33:15'},
#   {'id': 7056484,
#    'name': 'Big South Trail #944',
#    'type': 'Trail',
#    'summary': 'Needs Summary',
#    'difficulty': 'blueBlack',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Red Feather Lakes, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7056484/big-south-trail-944',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 10.6,
#    'ascent': 1694,
#    'descent': -450,
#    'high': 9707,
#    'low': 8449,
#    'longitude': -105.807,
#    'latitude': 40.6342,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7038780,
#    'name': 'Middle Fork #227',
#    'type': 'Trail',
#    'summary': 'A wilderness trail with countless views, wildflowers, and opportunities for wildlife viewing.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Ridgway, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7038780/middle-fork-227',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7038171_sqsmall_1555087658.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7038171_small_1555087658.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7038171_smallMed_1555087658.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7038171_medium_1555087658.jpg',
#    'length': 7.4,
#    'ascent': 2619,
#    'descent': -1143,
#    'high': 12598,
#    'low': 10027,
#    'longitude': -107.5254,
#    'latitude': 38.1434,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7054464,
#    'name': 'Hope Lake Trail',
#    'type': 'Trail',
#    'summary': 'A beautiful trail up to Hope Lake where you can find a tremendous amount of wildflowers in July and early August.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Mountain Village, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7054464/hope-lake-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 3.2,
#    'ascent': 1762,
#    'descent': -65,
#    'high': 12444,
#    'low': 10747,
#    'longitude': -107.8517,
#    'latitude': 37.805,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7032070,
#    'name': 'Moose Meadow Trail',
#    'type': 'Trail',
#    'summary': 'A fun hike in the woods.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Estes Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7032070/moose-meadow-trail',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1.1,
#    'ascent': 196,
#    'descent': -100,
#    'high': 8490,
#    'low': 8294,
#    'longitude': -105.464,
#    'latitude': 40.335,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7011022,
#    'name': 'CT - Segment 9: Tennessee Pass to Timberline Lake',
#    'type': 'Trail',
#    'summary': 'A beautiful trek from Tennessee Pass to Turquoise Lake featuring forest, streams, and some great views.',
#    'difficulty': 'greenBlue',
#    'stars': 4.8,
#    'starVotes': 5,
#    'location': 'Leadville North, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7011022/ct-segment-9-tennessee-pass-to-timberline-lake',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7033531_sqsmall_1554998204.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7033531_small_1554998204.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7033531_smallMed_1554998204.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7033531_medium_1554998204.jpg',
#    'length': 13.3,
#    'ascent': 2297,
#    'descent': -2674,
#    'high': 11713,
#    'low': 10057,
#    'longitude': -106.3113,
#    'latitude': 39.3626,
#    'conditionStatus': 'Bad / Closed',
#    'conditionDetails': 'Snowy, Fallen Trees - Very snowy above 11k feet. Tough to follow trail and a lot of postholing plus swarms of mosquitoes make for a tough long day',
#    'conditionDate': '2019-06-30 17:45:23'},
#   {'id': 7048665,
#    'name': 'Dream Weaver',
#    'type': 'Trail',
#    'summary': 'This is a rough and tumble singletrack near the Royal Gorge Campground.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Cañon City, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7048665/dream-weaver',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1.7,
#    'ascent': 89,
#    'descent': -398,
#    'high': 6910,
#    'low': 6519,
#    'longitude': -105.2913,
#    'latitude': 38.4659,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7000417,
#    'name': 'Alpine Ridge Trail',
#    'type': 'Trail',
#    'summary': 'A short trail leading to a great overlook.',
#    'difficulty': 'blue',
#    'stars': 4.5,
#    'starVotes': 12,
#    'location': 'Grand Lake, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7000417/alpine-ridge-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7000973_sqsmall_1554168256.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7000973_small_1554168256.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7000973_smallMed_1554168256.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7000973_medium_1554168256.jpg',
#    'length': 0.4,
#    'ascent': 190,
#    'descent': -12,
#    'high': 11985,
#    'low': 11795,
#    'longitude': -105.754,
#    'latitude': 40.4416,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7037408,
#    'name': 'Contrivance',
#    'type': 'Trail',
#    'summary': 'A fun and endlessly windy route up and over the ridge.',
#    'difficulty': 'blueBlack',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Fraser, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7037408/contrivance',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 3.9,
#    'ascent': 362,
#    'descent': -910,
#    'high': 9416,
#    'low': 8584,
#    'longitude': -105.8066,
#    'latitude': 40.0311,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7034281,
#    'name': 'Notch Mountain Trail #2000',
#    'type': 'Trail',
#    'summary': 'This extravaganza of switchbacks leads to spectacular, up-close views of Mount of the Holy Cross.',
#    'difficulty': 'blueBlack',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Minturn, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7034281/notch-mountain-trail-2000',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7034836_sqsmall_1555018049.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7034836_small_1555018049.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7034836_smallMed_1555018049.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7034836_medium_1555018049.jpg',
#    'length': 3,
#    'ascent': 1836,
#    'descent': -1,
#    'high': 13084,
#    'low': 11248,
#    'longitude': -106.4424,
#    'latitude': 39.4711,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7002938,
#    'name': 'Boy Scout',
#    'type': 'Trail',
#    'summary': "Access some excellent views of the Indian Peaks at May's Point from this trail.",
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Boulder, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7002938/boy-scout',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003658_sqsmall_1554234777.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7003658_small_1554234777.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003658_smallMed_1554234777.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7003658_medium_1554234777.jpg',
#    'length': 0.7,
#    'ascent': 139,
#    'descent': -124,
#    'high': 6865,
#    'low': 6765,
#    'longitude': -105.3032,
#    'latitude': 40.0041,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7038326,
#    'name': 'Lower Cement Creek Trail #636',
#    'type': 'Trail',
#    'summary': 'A fun singletrack next to Cement Creek Road.',
#    'difficulty': 'greenBlue',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Crested Butte, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7038326/lower-cement-creek-trail-636',
#    'imgSqSmall': '',
#    'imgSmall': '',
#    'imgSmallMed': '',
#    'imgMedium': '',
#    'length': 1.8,
#    'ascent': 249,
#    'descent': -22,
#    'high': 9050,
#    'low': 8823,
#    'longitude': -106.8589,
#    'latitude': 38.8226,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7040125,
#    'name': 'Flash of Gold',
#    'type': 'Trail',
#    'summary': 'A charming singletrack trail up to Buffalo Pass.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 1,
#    'location': 'Steamboat Springs, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7040125/flash-of-gold',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7038293_sqsmall_1555088041.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7038293_small_1555088041.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7038293_smallMed_1555088041.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7038293_medium_1555088041.jpg',
#    'length': 11.8,
#    'ascent': 2081,
#    'descent': -298,
#    'high': 10129,
#    'low': 8199,
#    'longitude': -106.7836,
#    'latitude': 40.5306,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7009020,
#    'name': 'Pyramid Peak Trail',
#    'type': 'Trail',
#    'summary': 'A brutal trail up the difficult 14er Pyramid Peak.',
#    'difficulty': 'dblack',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Snowmass Village, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7009020/pyramid-peak-trail',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7007143_sqsmall_1554322264.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7007143_small_1554322264.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7007143_smallMed_1554322264.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7007143_medium_1554322264.jpg',
#    'length': 2.5,
#    'ascent': 3818,
#    'descent': 0,
#    'high': 13958,
#    'low': 10141,
#    'longitude': -106.9603,
#    'latitude': 39.0901,
#    'conditionStatus': 'Unknown',
#    'conditionDetails': None,
#    'conditionDate': '1970-01-01 00:00:00'},
#   {'id': 7048782,
#    'name': 'Pulpit Ridge Loop',
#    'type': 'Trail',
#    'summary': 'A less-used trail in an extremely popular network.',
#    'difficulty': 'blue',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Colorado Springs, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7048782/pulpit-ridge-loop',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7057923_sqsmall_1555948299.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7057923_small_1555948299.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7057923_smallMed_1555948299.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7057923_medium_1555948299.jpg',
#    'length': 1,
#    'ascent': 252,
#    'descent': -192,
#    'high': 6611,
#    'low': 6366,
#    'longitude': -104.8039,
#    'latitude': 38.9069,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': '',
#    'conditionDate': '2019-06-23 21:08:09'},
#   {'id': 7057383,
#    'name': 'Fryingpan Lakes Trail #1921',
#    'type': 'Trail',
#    'summary': 'Needs Summary',
#    'difficulty': 'blueBlack',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Leadville North, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7057383/fryingpan-lakes-trail-1921',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7061516_sqsmall_1564886291.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7061516_small_1564886291.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7061516_smallMed_1564886291.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7061516_medium_1564886291.jpg',
#    'length': 4.3,
#    'ascent': 1098,
#    'descent': -57,
#    'high': 11025,
#    'low': 9980,
#    'longitude': -106.5303,
#    'latitude': 39.2445,
#    'conditionStatus': 'All Clear',
#    'conditionDetails': 'Mostly Dry - Some muddy spots but overall very clear and well maintained.',
#    'conditionDate': '2019-09-16 18:37:04'},
#   {'id': 7038821,
#    'name': "Devil's Tower Summit",
#    'type': 'Trail',
#    'summary': 'A set of metal stairs takes you to phenomenal 360-degree views at the last fire tower on the Front Range.',
#    'difficulty': 'greenBlue',
#    'stars': 5,
#    'starVotes': 2,
#    'location': 'Perry Park, Colorado',
#    'url': 'https://www.hikingproject.com/trail/7038821/devils-tower-summit',
#    'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7038050_sqsmall_1555087370.jpg',
#    'imgSmall': 'https://cdn-files.apstatic.com/hike/7038050_small_1555087370.jpg',
#    'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7038050_smallMed_1555087370.jpg',
#    'imgMedium': 'https://cdn-files.apstatic.com/hike/7038050_medium_1555087370.jpg',
#    'length': 0.1,
#    'ascent': 0,
#    'descent': -50,
#    'high': 9682,
#    'low': 9633,
#    'longitude': -105.1018,
#    'latitude': 39.2607,
#    'conditionStatus': 'Bad / Closed',
#    'conditionDetails': 'Trail is open to the meadow, but stairs and tower are closed for maintainance.',
#    'conditionDate': '2019-08-17 11:04:22'}],
#  'success': 1}

# %%
df=pd.DataFrame(response_json['trails'])
df
# Out:
#      ascent        conditionDate  \
# 0      7327  2019-09-20 15:12:10
# 1      2017  2019-09-23 09:15:01
# 2      2000  2019-09-30 07:21:48
# 3      2541  2019-08-10 16:37:58
# 4       661  2019-09-14 20:55:37
# 5      5525  2019-09-19 06:53:44
# 6      1261  2019-07-10 14:09:36
# 7      5409  2019-07-30 17:52:30
# 8      3169  2019-09-25 19:25:54
# 9      3162  2019-09-02 21:51:16
# 10     3479  2019-09-02 16:06:23
# 11     1293  2019-09-19 16:30:09
# 12     2766  2019-09-23 09:10:09
# 13     1037  2019-06-30 22:31:10
# 14      921  2019-08-23 19:33:37
# 15     1311  2019-07-21 14:20:07
# 16     1594  2019-08-11 12:20:56
# 17     2305  2019-08-03 18:22:28
# 18     1287  2019-09-19 15:04:39
# 19     2625  2019-09-22 14:13:06
# 20     1281  2019-08-27 15:10:20
# 21     4410  2019-09-14 20:57:08
# 22      918  2019-08-20 16:53:49
# 23     1058  2019-09-21 08:39:48
# 24     1083  2019-09-30 07:22:27
# 25      860  2019-09-28 13:42:27
# 26     6632  2019-09-25 23:22:10
# 27     3111  2019-08-23 15:31:44
# 28      883  2019-09-23 15:08:14
# 29      635  2019-08-23 08:10:22
# ..      ...                  ...
# 470      50  1970-01-01 00:00:00
# 471    1843  2019-06-29 10:15:41
# 472     427  1970-01-01 00:00:00
# 473    2259  2019-07-22 13:27:45
# 474    2611  1970-01-01 00:00:00
# 475    2577  1970-01-01 00:00:00
# 476    2981  1970-01-01 00:00:00
# 477    1397  1970-01-01 00:00:00
# 478    1995  2019-08-10 23:57:59
# 479     911  1970-01-01 00:00:00
# 480     252  1970-01-01 00:00:00
# 481     320  2019-07-14 13:53:40
# 482     878  1970-01-01 00:00:00
# 483     220  2019-07-15 16:33:15
# 484    1694  1970-01-01 00:00:00
# 485    2619  1970-01-01 00:00:00
# 486    1762  1970-01-01 00:00:00
# 487     196  1970-01-01 00:00:00
# 488    2297  2019-06-30 17:45:23
# 489      89  1970-01-01 00:00:00
# 490     190  1970-01-01 00:00:00
# 491     362  1970-01-01 00:00:00
# 492    1836  1970-01-01 00:00:00
# 493     139  1970-01-01 00:00:00
# 494     249  1970-01-01 00:00:00
# 495    2081  1970-01-01 00:00:00
# 496    3818  1970-01-01 00:00:00
# 497     252  2019-06-23 21:08:09
# 498    1098  2019-09-16 18:37:04
# 499       0  2019-08-17 11:04:22
#
#                                       conditionDetails conditionStatus  \
# 0    One messy section of avalanche debree, but oth...       All Clear
# 1                                                  Dry       All Clear
# 2    Muddy - Starting to get wet up there with cons...    Minor Issues
# 3                                                            All Clear
# 4                                                            All Clear
# 5                                                         Minor Issues
# 6    Dry - Careful of ticks in the high grass along...       All Clear
# 7                                                  Dry       All Clear
# 8                                                            All Clear
# 9                                                  Dry       All Clear
# 10                                                           All Clear
# 11                                            Some Mud       All Clear
# 12                                                 Dry       All Clear
# 13                                                 Dry       All Clear
# 14                                          Mostly Dry       All Clear
# 15                                                           All Clear
# 16                                                 Dry       All Clear
# 17                                                 Dry       All Clear
# 18                                                           All Clear
# 19                                          Dry, Snowy       All Clear
# 20                                                 Dry       All Clear
# 21                                                 Dry       All Clear
# 22    Dry - Rattlesnakes are very active in this area.       All Clear
# 23                                                 Dry       All Clear
# 24   Muddy - Starting to get wet up there with cons...    Minor Issues
# 25                                                 Dry       All Clear
# 26                                                           All Clear
# 27                                Mostly Dry, Some Mud    Minor Issues
# 28   The road leading to the trailhead of I-70 was ...    Bad / Closed
# 29   Dry - All clear! A few roots/rocks, but otherw...       All Clear
# ..                                                 ...             ...
# 470                                               None         Unknown
# 471   Dry - Super warm but the trail is dry and clear.       All Clear
# 472                                               None         Unknown
# 473                                         Mostly Dry       All Clear
# 474                                               None         Unknown
# 475                                               None         Unknown
# 476                                               None         Unknown
# 477                                               None         Unknown
# 478  Mostly Dry - 8/7/19 - Smallish ice patches bef...       All Clear
# 479                                               None         Unknown
# 480                                               None         Unknown
# 481                                                Dry       All Clear
# 482                                               None         Unknown
# 483                                                Dry       All Clear
# 484                                               None         Unknown
# 485                                               None         Unknown
# 486                                               None         Unknown
# 487                                               None         Unknown
# 488  Snowy, Fallen Trees - Very snowy above 11k fee...    Bad / Closed
# 489                                               None         Unknown
# 490                                               None         Unknown
# 491                                               None         Unknown
# 492                                               None         Unknown
# 493                                               None         Unknown
# 494                                               None         Unknown
# 495                                               None         Unknown
# 496                                               None         Unknown
# 497                                                          All Clear
# 498  Mostly Dry - Some muddy spots but overall very...       All Clear
# 499  Trail is open to the meadow, but stairs and to...    Bad / Closed
#
#      descent difficulty   high       id  \
# 0      -7329  blueBlack  12454  7001635
# 1      -2017       blue  10343  7006663
# 2      -1999  blueBlack  11014  7002175
# 3      -2540  blueBlack   8342  7000130
# 4       -651  greenBlue  10104  7000276
# 5      -5524      black  14214  7000487
# 6      -1282       blue   6800  7004226
# 7      -5492      black   8492  7011192
# 8      -3178  blueBlack  14184  7002074
# 9      -3162  blueBlack  12035  7006795
# 10     -3466  blueBlack  14246  7003636
# 11     -1309       blue  10194  7001090
# 12     -2766  blueBlack  11675  7001041
# 13     -1037       blue   7145  7003401
# 14      -921       blue   9357  7018920
# 15     -1312  blueBlack   6917  7004682
# 16     -1585  blueBlack   7335  7002439
# 17     -2277  blueBlack   8099  7011191
# 18     -1288       blue   7845  7003796
# 19     -2624  blueBlack  14016  7001739
# 20     -1280  blueBlack   6780  7000000
# 21     -4410  blueBlack  14405  7002038
# 22      -919       blue   7192  7004911
# 23     -1056       blue   6486  7000141
# 24     -1086       blue  10223  7001581
# 25      -860  greenBlue   9834  7006672
# 26     -6615  blueBlack  12528  7010213
# 27     -3110  blueBlack  13269  7006885
# 28      -883  blueBlack   7427  7011049
# 29      -633       blue   8685  7009683
# ..       ...        ...    ...      ...
# 470    -2168  blueBlack  12522  7036129
# 471      -15  blueBlack   9325  7031944
# 472     -241       blue  10705  7053735
# 473     -428      black  10566  7004347
# 474     -450  blueBlack  12476  7045607
# 475      -29     dblack  14118  7004855
# 476    -4831       blue  11879  7016088
# 477      -50     dblack  13098  7083749
# 478      -18     dblack  13966  7003336
# 479     -401       blue  10391  7001067
# 480      -97  greenBlue   9086  7033831
# 481     -189  greenBlue  10115  7033193
# 482    -1103  blueBlack  12152  7004781
# 483     -159       blue  11680  7033084
# 484     -450  blueBlack   9707  7056484
# 485    -1143       blue  12598  7038780
# 486      -65       blue  12444  7054464
# 487     -100       blue   8490  7032070
# 488    -2674  greenBlue  11713  7011022
# 489     -398       blue   6910  7048665
# 490      -12       blue  11985  7000417
# 491     -910  blueBlack   9416  7037408
# 492       -1  blueBlack  13084  7034281
# 493     -124       blue   6865  7002938
# 494      -22  greenBlue   9050  7038326
# 495     -298       blue  10129  7040125
# 496        0     dblack  13958  7009020
# 497     -192       blue   6611  7048782
# 498      -57  blueBlack  11025  7057383
# 499      -50  greenBlue   9682  7038821
#
#                                              imgMedium  \
# 0    https://cdn-files.apstatic.com/hike/7007432_me...
# 1    https://cdn-files.apstatic.com/hike/7002724_me...
# 2    https://cdn-files.apstatic.com/hike/7053480_me...
# 3    https://cdn-files.apstatic.com/hike/7005382_me...
# 4    https://cdn-files.apstatic.com/hike/7017842_me...
# 5    https://cdn-files.apstatic.com/hike/7037747_me...
# 6    https://cdn-files.apstatic.com/hike/7039883_me...
# 7    https://cdn-files.apstatic.com/hike/7048859_me...
# 8    https://cdn-files.apstatic.com/hike/7033447_me...
# 9    https://cdn-files.apstatic.com/hike/7034581_me...
# 10   https://cdn-files.apstatic.com/hike/7033157_me...
# 11   https://cdn-files.apstatic.com/hike/7017842_me...
# 12   https://cdn-files.apstatic.com/hike/7006507_me...
# 13   https://cdn-files.apstatic.com/hike/7034279_me...
# 14   https://cdn-files.apstatic.com/hike/7018971_me...
# 15   https://cdn-files.apstatic.com/hike/7002679_me...
# 16   https://cdn-files.apstatic.com/hike/7039625_me...
# 17   https://cdn-files.apstatic.com/hike/7003740_me...
# 18   https://cdn-files.apstatic.com/hike/7060379_me...
# 19   https://cdn-files.apstatic.com/hike/7001090_me...
# 20   https://cdn-files.apstatic.com/hike/7039883_me...
# 21   https://cdn-files.apstatic.com/hike/7035542_me...
# 22   https://cdn-files.apstatic.com/hike/7005037_me...
# 23   https://cdn-files.apstatic.com/hike/7044543_me...
# 24   https://cdn-files.apstatic.com/hike/7000658_me...
# 25   https://cdn-files.apstatic.com/hike/7029411_me...
# 26   https://cdn-files.apstatic.com/hike/7049405_me...
# 27   https://cdn-files.apstatic.com/hike/7024359_me...
# 28   https://cdn-files.apstatic.com/hike/7013652_me...
# 29   https://cdn-files.apstatic.com/hike/7000875_me...
# ..                                                 ...
# 470  https://cdn-files.apstatic.com/hike/7036354_me...
# 471  https://cdn-files.apstatic.com/hike/7058563_me...
# 472  https://cdn-files.apstatic.com/hike/7062068_me...
# 473  https://cdn-files.apstatic.com/hike/7023100_me...
# 474  https://cdn-files.apstatic.com/hike/7047988_me...
# 475  https://cdn-files.apstatic.com/hike/7037960_me...
# 476
# 477  https://cdn-files.apstatic.com/hike/7059934_me...
# 478  https://cdn-files.apstatic.com/hike/7002541_me...
# 479
# 480
# 481  https://cdn-files.apstatic.com/hike/7032730_me...
# 482  https://cdn-files.apstatic.com/hike/7049287_me...
# 483  https://cdn-files.apstatic.com/hike/7029823_me...
# 484
# 485  https://cdn-files.apstatic.com/hike/7038171_me...
# 486
# 487
# 488  https://cdn-files.apstatic.com/hike/7033531_me...
# 489
# 490  https://cdn-files.apstatic.com/hike/7000973_me...
# 491
# 492  https://cdn-files.apstatic.com/hike/7034836_me...
# 493  https://cdn-files.apstatic.com/hike/7003658_me...
# 494
# 495  https://cdn-files.apstatic.com/hike/7038293_me...
# 496  https://cdn-files.apstatic.com/hike/7007143_me...
# 497  https://cdn-files.apstatic.com/hike/7057923_me...
# 498  https://cdn-files.apstatic.com/hike/7061516_me...
# 499  https://cdn-files.apstatic.com/hike/7038050_me...
#
#                                               imgSmall  ... length  \
# 0    https://cdn-files.apstatic.com/hike/7007432_sm...  ...   27.1
# 1    https://cdn-files.apstatic.com/hike/7002724_sm...  ...   14.9
# 2    https://cdn-files.apstatic.com/hike/7053480_sm...  ...    8.3
# 3    https://cdn-files.apstatic.com/hike/7005382_sm...  ...    5.7
# 4    https://cdn-files.apstatic.com/hike/7017842_sm...  ...    3.3
# 5    https://cdn-files.apstatic.com/hike/7037747_sm...  ...   14.2
# 6    https://cdn-files.apstatic.com/hike/7039883_sm...  ...    5.3
# 7    https://cdn-files.apstatic.com/hike/7048859_sm...  ...   16.3
# 8    https://cdn-files.apstatic.com/hike/7033447_sm...  ...    6.4
# 9    https://cdn-files.apstatic.com/hike/7034581_sm...  ...   15.7
# 10   https://cdn-files.apstatic.com/hike/7033157_sm...  ...    8.3
# 11   https://cdn-files.apstatic.com/hike/7017842_sm...  ...    5.7
# 12   https://cdn-files.apstatic.com/hike/7006507_sm...  ...    8.2
# 13   https://cdn-files.apstatic.com/hike/7034279_sm...  ...    2.6
# 14   https://cdn-files.apstatic.com/hike/7018971_sm...  ...    5.3
# 15   https://cdn-files.apstatic.com/hike/7002679_sm...  ...    3.3
# 16   https://cdn-files.apstatic.com/hike/7039625_sm...  ...    7.6
# 17   https://cdn-files.apstatic.com/hike/7003740_sm...  ...    4.9
# 18   https://cdn-files.apstatic.com/hike/7060379_sm...  ...    5.9
# 19   https://cdn-files.apstatic.com/hike/7001090_sm...  ...    7.2
# 20   https://cdn-files.apstatic.com/hike/7039883_sm...  ...    3.2
# 21   https://cdn-files.apstatic.com/hike/7035542_sm...  ...    8.9
# 22   https://cdn-files.apstatic.com/hike/7005037_sm...  ...    4.3
# 23   https://cdn-files.apstatic.com/hike/7044543_sm...  ...    7.7
# 24   https://cdn-files.apstatic.com/hike/7000658_sm...  ...    6.0
# 25   https://cdn-files.apstatic.com/hike/7029411_sm...  ...    4.4
# 26   https://cdn-files.apstatic.com/hike/7049405_sm...  ...   26.5
# 27   https://cdn-files.apstatic.com/hike/7024359_sm...  ...    8.6
# 28   https://cdn-files.apstatic.com/hike/7013652_sm...  ...    3.9
# 29   https://cdn-files.apstatic.com/hike/7000875_sm...  ...    6.0
# ..                                                 ...  ...    ...
# 470  https://cdn-files.apstatic.com/hike/7036354_sm...  ...    3.3
# 471  https://cdn-files.apstatic.com/hike/7058563_sm...  ...    1.6
# 472  https://cdn-files.apstatic.com/hike/7062068_sm...  ...    2.2
# 473  https://cdn-files.apstatic.com/hike/7023100_sm...  ...    8.0
# 474  https://cdn-files.apstatic.com/hike/7047988_sm...  ...    6.7
# 475  https://cdn-files.apstatic.com/hike/7037960_sm...  ...    2.1
# 476                                                     ...   21.1
# 477  https://cdn-files.apstatic.com/hike/7059934_sm...  ...    1.2
# 478  https://cdn-files.apstatic.com/hike/7002541_sm...  ...    1.7
# 479                                                     ...    6.2
# 480                                                     ...    1.9
# 481  https://cdn-files.apstatic.com/hike/7032730_sm...  ...    3.0
# 482  https://cdn-files.apstatic.com/hike/7049287_sm...  ...    4.6
# 483  https://cdn-files.apstatic.com/hike/7029823_sm...  ...    1.0
# 484                                                     ...   10.6
# 485  https://cdn-files.apstatic.com/hike/7038171_sm...  ...    7.4
# 486                                                     ...    3.2
# 487                                                     ...    1.1
# 488  https://cdn-files.apstatic.com/hike/7033531_sm...  ...   13.3
# 489                                                     ...    1.7
# 490  https://cdn-files.apstatic.com/hike/7000973_sm...  ...    0.4
# 491                                                     ...    3.9
# 492  https://cdn-files.apstatic.com/hike/7034836_sm...  ...    3.0
# 493  https://cdn-files.apstatic.com/hike/7003658_sm...  ...    0.7
# 494                                                     ...    1.8
# 495  https://cdn-files.apstatic.com/hike/7038293_sm...  ...   11.8
# 496  https://cdn-files.apstatic.com/hike/7007143_sm...  ...    2.5
# 497  https://cdn-files.apstatic.com/hike/7057923_sm...  ...    1.0
# 498  https://cdn-files.apstatic.com/hike/7061516_sm...  ...    4.3
# 499  https://cdn-files.apstatic.com/hike/7038050_sm...  ...    0.1
#
#                         location  longitude    low  \
# 0     Snowmass Village, Colorado  -106.9407   9571
# 1               Granby, Colorado  -105.7463   8350
# 2           Estes Park, Colorado  -105.6403   9162
# 3              Boulder, Colorado  -105.2755   6103
# 4           Estes Park, Colorado  -105.6457   9476
# 5           Estes Park, Colorado  -105.5566   9412
# 6              Boulder, Colorado  -105.2979   5530
# 7             Superior, Colorado  -105.2582   5417
# 8         Breckenridge, Colorado  -106.0619  11006
# 9            Nederland, Colorado  -105.5951   8988
# 10          Georgetown, Colorado  -105.7846  11242
# 11          Estes Park, Colorado  -105.6461   9273
# 12          Estes Park, Colorado  -105.5566   9430
# 13    Glenwood Springs, Colorado  -107.1900   6108
# 14          Estes Park, Colorado  -105.5664   8511
# 15             Boulder, Colorado  -105.2830   5691
# 16          Coal Creek, Colorado  -105.3378   6439
# 17             Boulder, Colorado  -105.2928   5806
# 18     Manitou Springs, Colorado  -104.8903   6633
# 19          Georgetown, Colorado  -105.7102  11509
# 20             Boulder, Colorado  -105.2977   5521
# 21     Leadville North, Colorado  -106.4123  10063
# 22              Golden, Colorado  -105.2541   6289
# 23              Golden, Colorado  -105.2297   5851
# 24          Estes Park, Colorado  -105.6403   9136
# 25           Nederland, Colorado  -105.5951   8988
# 26           Nederland, Colorado  -105.5843   8820
# 27           Nederland, Colorado  -105.6341  10158
# 28             Genesee, Colorado  -105.3154   6563
# 29          Estes Park, Colorado  -105.6158   8063
# ..                           ...        ...    ...
# 470           Keystone, Colorado  -105.8732  10354
# 471  Air Force Academy, Colorado  -104.9034   7482
# 472          Centennial, Wyoming  -106.3239  10317
# 473             Walden, Colorado  -106.0104   8473
# 474           Keystone, Colorado  -105.8675  10315
# 475   Snowmass Village, Colorado  -107.0810  11562
# 476  Steamboat Springs, Colorado  -106.6849   8458
# 477       Silverthorne, Colorado  -106.1765  11746
# 478          Lake City, Colorado  -107.4929  11972
# 479  Steamboat Springs, Colorado  -106.6950   9831
# 480   Snowmass Village, Colorado  -106.9706   8916
# 481       Breckenridge, Colorado  -106.0299   9853
# 482        Winter Park, Colorado  -105.6982  11372
# 483        Winter Park, Colorado  -105.6657  11460
# 484  Red Feather Lakes, Colorado  -105.8070   8449
# 485            Ridgway, Colorado  -107.5254  10027
# 486   Mountain Village, Colorado  -107.8517  10747
# 487         Estes Park, Colorado  -105.4640   8294
# 488    Leadville North, Colorado  -106.3113  10057
# 489         Cañon City, Colorado  -105.2913   6519
# 490         Grand Lake, Colorado  -105.7540  11795
# 491             Fraser, Colorado  -105.8066   8584
# 492            Minturn, Colorado  -106.4424  11248
# 493            Boulder, Colorado  -105.3032   6765
# 494      Crested Butte, Colorado  -106.8589   8823
# 495  Steamboat Springs, Colorado  -106.7836   8199
# 496   Snowmass Village, Colorado  -106.9603  10141
# 497   Colorado Springs, Colorado  -104.8039   6366
# 498    Leadville North, Colorado  -106.5303   9980
# 499         Perry Park, Colorado  -105.1018   9633
#
#                                                   name  starVotes  stars  \
# 0                                       Four Pass Loop        142    5.0
# 1                          Monarch Lake to Crater Lake         67    4.9
# 2                                             Sky Pond        228    4.9
# 3                               Bear Peak Out and Back        108    4.6
# 4                                         Emerald Lake        263    4.7
# 5                           Longs Peak - Keyhole Route         85    4.8
# 6                            Sunshine Lion's Lair Loop        103    4.5
# 7                             Boulder Skyline Traverse         71    4.7
# 8                                        Quandary Peak        104    4.4
# 9                                   High Lonesome Loop         68    4.8
# 10                             Grays and Torreys Peaks        102    4.4
# 11                         Best of Bear Lake Area Loop         90    4.6
# 12                                          Chasm Lake         77    4.7
# 13                                        Hanging Lake        117    4.6
# 14                                  Ouzel Falls & Back         96    4.5
# 15                             Royal Arch Out and Back        145    4.4
# 16                                        Walker Ranch        119    4.5
# 17          Green Mountain via Ranger/Saddle Rock Loop         77    4.5
# 18                              Section 16/Palmer Loop         71    4.5
# 19                         Mt. Bierstadt – West Slopes         91    4.3
# 20                                  Mount Sanitas Loop        102    4.1
# 21                                          Mt. Elbert         70    4.4
# 22                             Mt. Galbraith Park Loop         77    4.0
# 23                              North Table Loop Trail         76    3.9
# 24                                           Loch Vale         58    4.8
# 25                                 Hessie to Lost Lake         64    4.2
# 26                                Pawnee-Buchanan Loop         39    4.8
# 27                                  South Arapaho Peak         43    4.8
# 28                  Chavez and Beaver Brook Trail Loop         56    4.4
# 29                                       Cub Lake Loop         63    4.3
# ..                                                 ...        ...    ...
# 470                                      Lenawee Trail          2    5.0
# 471                                  Eagles Peak Trail         11    4.4
# 472                                  Tipple Trail #293          2    5.0
# 473                                   Clear Lake Trail          2    5.0
# 474                         Saints John Road (FDR 275)          2    5.0
# 475                                       Capitol Peak          2    5.0
# 476       CDT: Buffalo Pass to North Lake (CO Sec. 43)          2    5.0
# 477                                           Red Peak          2    5.0
# 478                        Wetterhorn Peak Trail #9256          2    5.0
# 479                                      Mountain View          2    5.0
# 480                                        Ditch Trail          2    5.0
# 481                                   Blue River Trail          8    4.6
# 482           CDT: South Boulder Creek to Rollins Pass          2    5.0
# 483                                   Rock House Trail          2    5.0
# 484                               Big South Trail #944          2    5.0
# 485                                   Middle Fork #227          2    5.0
# 486                                    Hope Lake Trail          2    5.0
# 487                                 Moose Meadow Trail          2    5.0
# 488  CT - Segment 9: Tennessee Pass to Timberline Lake          5    4.8
# 489                                       Dream Weaver          2    5.0
# 490                                 Alpine Ridge Trail         12    4.5
# 491                                        Contrivance          2    5.0
# 492                         Notch Mountain Trail #2000          2    5.0
# 493                                          Boy Scout          2    5.0
# 494                      Lower Cement Creek Trail #636          2    5.0
# 495                                      Flash of Gold          1    5.0
# 496                                 Pyramid Peak Trail          2    5.0
# 497                                  Pulpit Ridge Loop          2    5.0
# 498                        Fryingpan Lakes Trail #1921          2    5.0
# 499                               Devil's Tower Summit          2    5.0
#
#                                                summary           type  \
# 0    An all-time journey over four 12,500' alpine p...  Featured Hike
# 1    Gorgeous scenery with waterfalls and wildflowe...  Featured Hike
# 2    Sky Pond is in a deep valley carved by Taylor ...  Featured Hike
# 3    A must-do hike for Boulder locals and visitors...  Featured Hike
# 4    An easy to moderate out and back that culminat...  Featured Hike
# 5    A beautiful and rewarding route to the summit ...  Featured Hike
# 6    Great Mount Sanitas views are the reward for t...  Featured Hike
# 7          The classic long mountain route in Boulder.  Featured Hike
# 8    A popular and easy 14er just outside Breckenri...  Featured Hike
# 9    A backcountry trail providing the best of high...  Featured Hike
# 10   Summit two 14ers on the Continental Divide alo...  Featured Hike
# 11   A splendid loop highlighting the natural beaut...  Featured Hike
# 12   A must-do RMNP hike that leads to and from an ...  Featured Hike
# 13   A true treasure of Glenwood Canyon, Hanging La...  Featured Hike
# 14   Three waterfalls, one mountain creek, and 5.5 ...  Featured Hike
# 15   A classic Boulder hike to a natural arch with ...  Featured Hike
# 16   An awesome and challenging hike near Boulder w...  Featured Hike
# 17   A loop with a variety of terrain, a lot of cli...  Featured Hike
# 18                A favorite loop in the Springs area.  Featured Hike
# 19   An easy intro to Colorado's 14ers on the stand...  Featured Hike
# 20   Very popular and scenic loop right from the ed...  Featured Hike
# 21   The highest mountain in Colorado is also one o...  Featured Hike
# 22   A fun singletrack lollipop loop up and around ...  Featured Hike
# 23   A rolling grassland trail that circumnavigates...  Featured Hike
# 24   One of RMNP's premier hikes featuring some of ...  Featured Hike
# 25   A relatively approachable alpine hike with eas...  Featured Hike
# 26              One of the top long loops in Colorado.  Featured Hike
# 27   One of the most popular and worthwhile summits...  Featured Hike
# 28   A rolling trail with lots of shade, following ...  Featured Hike
# 29   A loop from the open meadows of Moraine Park u...  Featured Hike
# ..                                                 ...            ...
# 470                          A nice trail to hike down          Trail
# 471  A moderately difficult trail up to Eagles Peak...          Trail
# 472  A wooded trail with abundant wildflowers and s...          Trail
# 473  A great route for long-distance hikers, this t...          Trail
# 474  Visit the Ghost Town of Saints John and the ne...          Trail
# 475  Regarded by many as Colorado's hardest 14er, C...          Trail
# 476                                     Needs Adoption          Trail
# 477  One of the most accessible and dramatic high p...          Trail
# 478  This trail offers pure world class hiking and ...          Trail
# 479  A scenic high country route connecting to Stea...          Trail
# 480  Enjoy beautiful views along this easy trail th...          Trail
# 481  A very fun out and back trail from Breckenridg...          Trail
# 482  Part of the Continental Divide Scenic Trail, t...          Trail
# 483  This trail extends St. Mary's Glacier Trail an...          Trail
# 484                                      Needs Summary          Trail
# 485  A wilderness trail with countless views, wildf...          Trail
# 486  A beautiful trail up to Hope Lake where you ca...          Trail
# 487                           A fun hike in the woods.          Trail
# 488  A beautiful trek from Tennessee Pass to Turquo...          Trail
# 489  This is a rough and tumble singletrack near th...          Trail
# 490         A short trail leading to a great overlook.          Trail
# 491  A fun and endlessly windy route up and over th...          Trail
# 492  This extravaganza of switchbacks leads to spec...          Trail
# 493  Access some excellent views of the Indian Peak...          Trail
# 494       A fun singletrack next to Cement Creek Road.          Trail
# 495   A charming singletrack trail up to Buffalo Pass.          Trail
# 496  A brutal trail up the difficult 14er Pyramid P...          Trail
# 497  A less-used trail in an extremely popular netw...          Trail
# 498                                      Needs Summary          Trail
# 499  A set of metal stairs takes you to phenomenal ...          Trail
#
#                                                    url
# 0    https://www.hikingproject.com/trail/7001635/fo...
# 1    https://www.hikingproject.com/trail/7006663/mo...
# 2    https://www.hikingproject.com/trail/7002175/sk...
# 3    https://www.hikingproject.com/trail/7000130/be...
# 4    https://www.hikingproject.com/trail/7000276/em...
# 5    https://www.hikingproject.com/trail/7000487/lo...
# 6    https://www.hikingproject.com/trail/7004226/su...
# 7    https://www.hikingproject.com/trail/7011192/bo...
# 8    https://www.hikingproject.com/trail/7002074/qu...
# 9    https://www.hikingproject.com/trail/7006795/hi...
# 10   https://www.hikingproject.com/trail/7003636/gr...
# 11   https://www.hikingproject.com/trail/7001090/be...
# 12   https://www.hikingproject.com/trail/7001041/ch...
# 13   https://www.hikingproject.com/trail/7003401/ha...
# 14   https://www.hikingproject.com/trail/7018920/ou...
# 15   https://www.hikingproject.com/trail/7004682/ro...
# 16   https://www.hikingproject.com/trail/7002439/wa...
# 17   https://www.hikingproject.com/trail/7011191/gr...
# 18   https://www.hikingproject.com/trail/7003796/se...
# 19   https://www.hikingproject.com/trail/7001739/mt...
# 20   https://www.hikingproject.com/trail/7000000/mo...
# 21   https://www.hikingproject.com/trail/7002038/mt...
# 22   https://www.hikingproject.com/trail/7004911/mt...
# 23   https://www.hikingproject.com/trail/7000141/no...
# 24   https://www.hikingproject.com/trail/7001581/lo...
# 25   https://www.hikingproject.com/trail/7006672/he...
# 26   https://www.hikingproject.com/trail/7010213/pa...
# 27   https://www.hikingproject.com/trail/7006885/so...
# 28   https://www.hikingproject.com/trail/7011049/ch...
# 29   https://www.hikingproject.com/trail/7009683/cu...
# ..                                                 ...
# 470  https://www.hikingproject.com/trail/7036129/le...
# 471  https://www.hikingproject.com/trail/7031944/ea...
# 472  https://www.hikingproject.com/trail/7053735/ti...
# 473  https://www.hikingproject.com/trail/7004347/cl...
# 474  https://www.hikingproject.com/trail/7045607/sa...
# 475  https://www.hikingproject.com/trail/7004855/ca...
# 476  https://www.hikingproject.com/trail/7016088/cd...
# 477  https://www.hikingproject.com/trail/7083749/re...
# 478  https://www.hikingproject.com/trail/7003336/we...
# 479  https://www.hikingproject.com/trail/7001067/mo...
# 480  https://www.hikingproject.com/trail/7033831/di...
# 481  https://www.hikingproject.com/trail/7033193/bl...
# 482  https://www.hikingproject.com/trail/7004781/cd...
# 483  https://www.hikingproject.com/trail/7033084/ro...
# 484  https://www.hikingproject.com/trail/7056484/bi...
# 485  https://www.hikingproject.com/trail/7038780/mi...
# 486  https://www.hikingproject.com/trail/7054464/ho...
# 487  https://www.hikingproject.com/trail/7032070/mo...
# 488  https://www.hikingproject.com/trail/7011022/ct...
# 489  https://www.hikingproject.com/trail/7048665/dr...
# 490  https://www.hikingproject.com/trail/7000417/al...
# 491  https://www.hikingproject.com/trail/7037408/co...
# 492  https://www.hikingproject.com/trail/7034281/no...
# 493  https://www.hikingproject.com/trail/7002938/bo...
# 494  https://www.hikingproject.com/trail/7038326/lo...
# 495  https://www.hikingproject.com/trail/7040125/fl...
# 496  https://www.hikingproject.com/trail/7009020/py...
# 497  https://www.hikingproject.com/trail/7048782/pu...
# 498  https://www.hikingproject.com/trail/7057383/fr...
# 499  https://www.hikingproject.com/trail/7038821/de...
#
# [500 rows x 23 columns]

# %%
database_path = "C:/Users/blake/Desktop/Git Hub Repository/Project/Solved/Hiking/db/hiking.sqlite"
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# %%
df.to_sql(name='hiking', con=engine, if_exists='append', index=True)
